# %% [markdown]
# Задание 1
#
# Напишите функцию, которая классифицирует фильмы из материалов занятия по правилам:
#
# оценка 2 и ниже — низкий рейтинг;
#
# оценка 4 и ниже — средний рейтинг;
#
# оценка 4.5 и 5 — высокий рейтинг.
#
# Результат классификации запишите в столбец class.

# %%
import pandas as pd

# %%
ratings_df = pd.read_csv('ratings.csv')
ratings_df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
def classify_movies(ratings_df):
    ratings_df['class'] = pd.cut(x=ratings_df['rating'],
                                 bins=[0, 2, 4, 5],
                                 labels=['низкий рейтинг', 'средний рейтинг', 'высокий рейтинг'])
    return ratings_df

# %%
classified_df = classify_movies(ratings_df)
print(classified_df.head())
# Out:
#    userId  movieId  rating   timestamp            class
# 0       1       31     2.5  1260759144  средний рейтинг
# 1       1     1029     3.0  1260759179  средний рейтинг
# 2       1     1061     3.0  1260759182  средний рейтинг
# 3       1     1129     2.0  1260759185   низкий рейтинг
# 4       1     1172     4.0  1260759205  средний рейтинг

# %% [markdown]
# Задание 2
#
# Используйте файл keywords.csv.
#
# Нужно написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определённому региону. Т. е. если поисковый запрос содержит название города региона, то в столбце ‘region’ пишется название этого региона. Если поисковый запрос не содержит названия города, то ставим ‘undefined’.
#
# Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:
#
# geo_data = {
#
# 'Центр': ['москва', 'тула', 'ярославль'],
#
# 'Северо-Запад': ['петербург', 'псков', 'мурманск'],
#
# 'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
# }
#
# Результат классификации запишите в отдельный столбец region.

# %%
import pandas as pd
key = pd.read_csv('keywords.csv')
key.head()
# Out:
#          keyword     shows
# 0             вк  64292779
# 1  одноклассники  63810309
# 2          порно  41747114
# 3           ютуб  39995567
# 4      вконтакте  21014195

# %%
geo_data = {
'Центр': ['москва', 'тула', 'ярославль'],
'Северо-Запад': ['петербург', 'псков', 'мурманск'],
'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск'] }

# %%
# определяем функцию классификации
def find_region(keyword):
    for region, cities in geo_data.items():
        for city in cities:
            if city in keyword:
                return region
    return 'undefined'

# %%
# применяем функцию к столбцу keyword и создаем новый столбец region
key['region'] = key['keyword'].apply(find_region)
key.head()
# Out:
#          keyword     shows     region
# 0             вк  64292779  undefined
# 1  одноклассники  63810309  undefined
# 2          порно  41747114  undefined
# 3           ютуб  39995567  undefined
# 4      вконтакте  21014195  undefined

# %% [markdown]
# Задание 3 (бонусное)
#
# Есть мнение, что раньше снимали настоящее кино, не то что сейчас. Ваша задача — проверить это утверждение, используя файлы с рейтингами фильмов из прошлого домашнего занятия: файл movies.csv и ratings.csv из базы. Нужно проверить, верно ли, что с ростом года выпуска фильма его средний рейтинг становится ниже.
#
# Вы не будете затрагивать субьективные факторы выставления этих рейтингов, а пройдётесь по алгоритму:
#
# В переменную years запишите список из всех годов с 1950 по 2010 года.
#
# Напишите функцию production_year, которая каждой строке из названия фильма выставляет год выпуска. Не все названия фильмов содержат год выпуска в одинаковом формате, поэтому используйте алгоритм:
#
# для каждой строки пройдите по всем годам списка years;
# если номер года присутствует в названии фильма, то функция возвращает этот год, как год выпуска;
# если ни один из номеров года списка years не встретился в названии фильма, то возвращается 1900 год.
# Запишите год выпуска фильма по алгоритму пункта 2 в новый столбец ‘year’.
#
# Посчитайте средний рейтинг всех фильмов для каждого значения столбца ‘year’ и отсортируйте результат по убыванию рейтинга.

# %%
ratings_df = pd.read_csv('ratings.csv')
ratings_df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
movies_df = pd.read_csv('movies.csv')
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
#  присоединение таблиц
films_df = ratings_df.merge(movies_df, on='movieId', how='left')
films_df.head()
# Out:
#    userId  movieId  rating   timestamp  \
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205
#
#                                             title  \
# 0                          Dangerous Minds (1995)
# 1                                    Dumbo (1941)
# 2                                 Sleepers (1996)
# 3                     Escape from New York (1981)
# 4  Cinema Paradiso (Nuovo cinema Paradiso) (1989)
#
#                              genres
# 0                             Drama
# 1  Animation|Children|Drama|Musical
# 2                          Thriller
# 3  Action|Adventure|Sci-Fi|Thriller
# 4                             Drama

# %%
# Создаем список лет

years = range(1950, 2011)

# %%
# функция для определения года выпуска фильма:


def production_year(title):
    for year in years:
        if str(year) in title:
            return year
    return 1900

# %%
# Применяем эту функцию для каждой строки в столбце title и создаем новый столбец year:


films_df['year'] = films_df['title'].apply(production_year)
films_df.head()
# Out:
#    userId  movieId  rating   timestamp  \
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205
#
#                                             title  \
# 0                          Dangerous Minds (1995)
# 1                                    Dumbo (1941)
# 2                                 Sleepers (1996)
# 3                     Escape from New York (1981)
# 4  Cinema Paradiso (Nuovo cinema Paradiso) (1989)
#
#                              genres  year
# 0                             Drama  1995
# 1  Animation|Children|Drama|Musical  1900
# 2                          Thriller  1996
# 3  Action|Adventure|Sci-Fi|Thriller  1981
# 4                             Drama  1989

# %%
# Группируем фильмы по году выпуска и считаем средний рейтинг


ratings_mean = films_df.groupby('movieId').mean()['rating']
ratings_by_year = films_df.groupby('year').mean()['rating']
sorted_ratings = ratings_by_year.sort_values(ascending=False)

print(sorted_ratings)
# Out:
# year
# 1957    4.014241
# 1972    4.011136
# 1952    4.000000
# 1954    3.994220
# 1951    3.983539
#           ...
# 2005    3.448434
# 2003    3.444777
# 1996    3.426600
# 1997    3.415764
# 2000    3.356104
# Name: rating, Length: 62, dtype: float64
# <ipython-input-74-ff47928d0c87>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ratings_mean = films_df.groupby('movieId').mean()['rating']
# <ipython-input-74-ff47928d0c87>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ratings_by_year = films_df.groupby('year').mean()['rating']
